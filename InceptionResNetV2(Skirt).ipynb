# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# IMPORT MODULES
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.layers import Input, Dense, GlobalAveragePooling2D
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
import matplotlib.pyplot as plt
from keras.models import Model
from keras.applications import InceptionResNetV2

# -----------------------------1.客製化模型--------------------------------
# 載入keras模型(更換輸出圖片尺寸)
# model = InceptionResNetV2(include_top=False,
#                  weights='imagenet',
#                  input_tensor=Input(shape=(80, 80, 3))
#                  )

# # 定義輸出層
# x = model.output
# x = GlobalAveragePooling2D()(x)
# predictions = Dense(3, activation='softmax')(x)  # Change to 3 and softmax activation
# model = Model(inputs=model.input, outputs=predictions)

# # 編譯模型
# model.compile(optimizer=Adam,
#               loss='categorical_crossentropy',  # Change to categorical_crossentropy
#               metrics=['accuracy'])

# %%
# 設定earlystop條件
estop = EarlyStopping(monitor='val_loss', patience=10, mode='min', verbose=1)

# 設定模型儲存條件
checkpoint = ModelCheckpoint('InceptionResNetV2_checkpoint_v2.h5', verbose=1,
                          monitor='val_loss', save_best_only=True,
                          mode='min')

# 設定lr降低條件(0.001 → 0.0005 → 0.00025 → 0.000125 → 0.0001)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                           patience=5, mode='min', verbose=1,
                           min_lr=1e-5)

# %%
import random
import pandas as pd
import glob

Naturel= glob.glob("/content/drive/MyDrive/第三版資料集/窄裙、長裙、中長裙/Naturel/*")
random.shuffle(Naturel)
Straight= glob.glob("/content/drive/MyDrive/第三版資料集/窄裙、長裙、中長裙/Straight/*")
random.shuffle(Straight)
Wave= glob.glob("/content/drive/MyDrive/第三版資料集/窄裙、長裙、中長裙/Wave/*")
random.shuffle(Wave)
print(len(Naturel), len(Straight), len(Wave))
train = pd.DataFrame({
    "filename": Naturel[:1] + Straight[:3] + Wave[:90],
    "class": [0] * 1 + [1] * 3  + [2] * 90
})

validate = pd.DataFrame({
    "filename": Naturel[:1] + Straight[3:5] + Wave[90:95],
    "class": [0] * 1 + [1] * 2 + [2] * 5
})

test = pd.DataFrame({
    "filename": Naturel[:1] + Straight[5:7] + Wave[95:100],
    "class": [0] * 1 + [1] * 2 + [2] * 5
})
train
# Out:
# 3 7 101
#                                              filename  class
# 0   /content/drive/MyDrive/第三版資料集/窄裙、長裙、中長裙/Nature...      0
# 1   /content/drive/MyDrive/第三版資料集/窄裙、長裙、中長裙/Straig...      1
# 2   /content/drive/MyDrive/第三版資料集/窄裙、長裙、中長裙/Straig...      1
# 3   /content/drive/MyDrive/第三版資料集/窄裙、長裙、中長裙/Straig...      1
# 4   /content/drive/MyDrive/第三版資料集/窄裙、長裙、中長裙/Wave/窄...      2
# ..                                                ...    ...
# 89  /content/drive/MyDrive/第三版資料集/窄裙、長裙、中長裙/Wave/短...      2
# 90  /content/drive/MyDrive/第三版資料集/窄裙、長裙、中長裙/Wave/窄...      2
# 91  /content/drive/MyDrive/第三版資料集/窄裙、長裙、中長裙/Wave/窄...      2
# 92  /content/drive/MyDrive/第三版資料集/窄裙、長裙、中長裙/Wave/長...      2
# 93  /content/drive/MyDrive/第三版資料集/窄裙、長裙、中長裙/Wave/窄...      2
#
# [94 rows x 2 columns]

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.inception_resnet_v2 import preprocess_input 

# from tensorflow.keras.applications.vgg16 import preprocess_input
# 資料增強: zoom:放大(1.2) shear:偏斜(0.2) 水平翻轉


train_datagen = ImageDataGenerator(
    shear_range=0.2, zoom_range=0.2, horizontal_flip=True, preprocessing_function=preprocess_input
)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

training_set = train_datagen.flow_from_dataframe(
    train,
    ".",
    target_size=(80, 80),
    batch_size=32,
    class_mode="raw")  # <- Change this to 'categorical'
validate_set = test_datagen.flow_from_dataframe(
    validate,
    ".",
    target_size=(80, 80),
    batch_size=32,
    class_mode="raw")  # <- Change this to 'categorical'
test_set = test_datagen.flow_from_dataframe(
    test,
    ".",
    target_size=(80, 80),
    batch_size=32,
    class_mode="raw")  # <- Change this to 'categorical'

import matplotlib.pyplot as plt
# __next__: (圖片, 答案)
batch = training_set.__next__()[0]
print(batch.shape)
plt.figure(figsize=(5, 5))
for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.imshow(batch[i])
    plt.axis("off")
# Out:
# Found 94 validated image filenames.
# Found 8 validated image filenames.
# Found 8 validated image filenames.
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (32, 80, 80, 3)

# %%
# from keras.layers import Input, Dense, GlobalAveragePooling2D, Flatten, Dropout
# from keras.models import Model
# from keras.applications import InceptionResNetV2

# inception_resnet = InceptionResNetV2(include_top=False, input_shape=(80,80, 3))
# inception_resnet.summary()

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.applications import InceptionResNetV2

inception_resnet_v2 = InceptionResNetV2(include_top=False, input_shape=(80, 80, 3))

# Freeze layers up to mixed_6a
for layer in inception_resnet_v2.layers[:781]:
    layer.trainable = False

# Add new layers
x = BatchNormalization()(inception_resnet_v2.output)
x = GlobalAveragePooling2D()(x)
x = Dense(3, activation="softmax")(x)

# Create new model
model = Model(inputs=inception_resnet_v2.input, outputs=x)

# Print model summary
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 80, 80, 3)]  0           []
#
#  conv2d_406 (Conv2D)            (None, 39, 39, 32)   864         ['input_3[0][0]']
#
#  batch_normalization_408 (Batch  (None, 39, 39, 32)  96          ['conv2d_406[0][0]']
#  Normalization)
#
#  activation_406 (Activation)    (None, 39, 39, 32)   0           ['batch_normalization_408[0][0]']
#
#  conv2d_407 (Conv2D)            (None, 37, 37, 32)   9216        ['activation_406[0][0]']
#
#  batch_normalization_409 (Batch  (None, 37, 37, 32)  96          ['conv2d_407[0][0]']
#  Normalization)
#
#  activation_407 (Activation)    (None, 37, 37, 32)   0           ['batch_normalization_409[0][0]']
#
#  conv2d_408 (Conv2D)            (None, 37, 37, 64)   18432       ['activation_407[0][0]']
#
#  batch_normalization_410 (Batch  (None, 37, 37, 64)  192         ['conv2d_408[0][0]']
#  Normalization)
#
#  activation_408 (Activation)    (None, 37, 37, 64)   0           ['batch_normalization_410[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 18, 18, 64)  0           ['activation_408[0][0]']
#
#  conv2d_409 (Conv2D)            (None, 18, 18, 80)   5120        ['max_pooling2d_8[0][0]']
#
#  batch_normalization_411 (Batch  (None, 18, 18, 80)  240         ['conv2d_409[0][0]']
#  Normalization)
#
#  activation_409 (Activation)    (None, 18, 18, 80)   0           ['batch_normalization_411[0][0]']
#
#  conv2d_410 (Conv2D)            (None, 16, 16, 192)  138240      ['activation_409[0][0]']
#
#  batch_normalization_412 (Batch  (None, 16, 16, 192)  576        ['conv2d_410[0][0]']
#  Normalization)
#
#  activation_410 (Activation)    (None, 16, 16, 192)  0           ['batch_normalization_412[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 7, 7, 192)   0           ['activation_410[0][0]']
#
#  conv2d_414 (Conv2D)            (None, 7, 7, 64)     12288       ['max_pooling2d_9[0][0]']
#
#  batch_normalization_416 (Batch  (None, 7, 7, 64)    192         ['conv2d_414[0][0]']
#  Normalization)
#
#  activation_414 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_416[0][0]']
#
#  conv2d_412 (Conv2D)            (None, 7, 7, 48)     9216        ['max_pooling2d_9[0][0]']
#
#  conv2d_415 (Conv2D)            (None, 7, 7, 96)     55296       ['activation_414[0][0]']
#
#  batch_normalization_414 (Batch  (None, 7, 7, 48)    144         ['conv2d_412[0][0]']
#  Normalization)
#
#  batch_normalization_417 (Batch  (None, 7, 7, 96)    288         ['conv2d_415[0][0]']
#  Normalization)
#
#  activation_412 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_414[0][0]']
#
#  activation_415 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_417[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 7, 7, 192)   0           ['max_pooling2d_9[0][0]']
#  oling2D)
#
#  conv2d_411 (Conv2D)            (None, 7, 7, 96)     18432       ['max_pooling2d_9[0][0]']
#
#  conv2d_413 (Conv2D)            (None, 7, 7, 64)     76800       ['activation_412[0][0]']
#
#  conv2d_416 (Conv2D)            (None, 7, 7, 96)     82944       ['activation_415[0][0]']
#
#  conv2d_417 (Conv2D)            (None, 7, 7, 64)     12288       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_413 (Batch  (None, 7, 7, 96)    288         ['conv2d_411[0][0]']
#  Normalization)
#
#  batch_normalization_415 (Batch  (None, 7, 7, 64)    192         ['conv2d_413[0][0]']
#  Normalization)
#
#  batch_normalization_418 (Batch  (None, 7, 7, 96)    288         ['conv2d_416[0][0]']
#  Normalization)
#
#  batch_normalization_419 (Batch  (None, 7, 7, 64)    192         ['conv2d_417[0][0]']
#  Normalization)
#
#  activation_411 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_413[0][0]']
#
#  activation_413 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_415[0][0]']
#
#  activation_416 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_418[0][0]']
#
#  activation_417 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_419[0][0]']
#
#  mixed_5b (Concatenate)         (None, 7, 7, 320)    0           ['activation_411[0][0]',
#                                                                   'activation_413[0][0]',
#                                                                   'activation_416[0][0]',
#                                                                   'activation_417[0][0]']
#
#  conv2d_421 (Conv2D)            (None, 7, 7, 32)     10240       ['mixed_5b[0][0]']
#
#  batch_normalization_423 (Batch  (None, 7, 7, 32)    96          ['conv2d_421[0][0]']
#  Normalization)
#
#  activation_421 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_423[0][0]']
#
#  conv2d_419 (Conv2D)            (None, 7, 7, 32)     10240       ['mixed_5b[0][0]']
#
#  conv2d_422 (Conv2D)            (None, 7, 7, 48)     13824       ['activation_421[0][0]']
#
#  batch_normalization_421 (Batch  (None, 7, 7, 32)    96          ['conv2d_419[0][0]']
#  Normalization)
#
#  batch_normalization_424 (Batch  (None, 7, 7, 48)    144         ['conv2d_422[0][0]']
#  Normalization)
#
#  activation_419 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_421[0][0]']
#
#  activation_422 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_424[0][0]']
#
#  conv2d_418 (Conv2D)            (None, 7, 7, 32)     10240       ['mixed_5b[0][0]']
#
#  conv2d_420 (Conv2D)            (None, 7, 7, 32)     9216        ['activation_419[0][0]']
#
#  conv2d_423 (Conv2D)            (None, 7, 7, 64)     27648       ['activation_422[0][0]']
#
#  batch_normalization_420 (Batch  (None, 7, 7, 32)    96          ['conv2d_418[0][0]']
#  Normalization)
#
#  batch_normalization_422 (Batch  (None, 7, 7, 32)    96          ['conv2d_420[0][0]']
#  Normalization)
#
#  batch_normalization_425 (Batch  (None, 7, 7, 64)    192         ['conv2d_423[0][0]']
#  Normalization)
#
#  activation_418 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_420[0][0]']
#
#  activation_420 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_422[0][0]']
#
#  activation_423 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_425[0][0]']
#
#  block35_1_mixed (Concatenate)  (None, 7, 7, 128)    0           ['activation_418[0][0]',
#                                                                   'activation_420[0][0]',
#                                                                   'activation_423[0][0]']
#
#  block35_1_conv (Conv2D)        (None, 7, 7, 320)    41280       ['block35_1_mixed[0][0]']
#
#  custom_scale_layer_80 (CustomS  (None, 7, 7, 320)   0           ['mixed_5b[0][0]',
#  caleLayer)                                                       'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)      (None, 7, 7, 320)    0           ['custom_scale_layer_80[0][0]']
#
#  conv2d_427 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_1_ac[0][0]']
#
#  batch_normalization_429 (Batch  (None, 7, 7, 32)    96          ['conv2d_427[0][0]']
#  Normalization)
#
#  activation_427 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_429[0][0]']
#
#  conv2d_425 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_1_ac[0][0]']
#
#  conv2d_428 (Conv2D)            (None, 7, 7, 48)     13824       ['activation_427[0][0]']
#
#  batch_normalization_427 (Batch  (None, 7, 7, 32)    96          ['conv2d_425[0][0]']
#  Normalization)
#
#  batch_normalization_430 (Batch  (None, 7, 7, 48)    144         ['conv2d_428[0][0]']
#  Normalization)
#
#  activation_425 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_427[0][0]']
#
#  activation_428 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_430[0][0]']
#
#  conv2d_424 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_1_ac[0][0]']
#
#  conv2d_426 (Conv2D)            (None, 7, 7, 32)     9216        ['activation_425[0][0]']
#
#  conv2d_429 (Conv2D)            (None, 7, 7, 64)     27648       ['activation_428[0][0]']
#
#  batch_normalization_426 (Batch  (None, 7, 7, 32)    96          ['conv2d_424[0][0]']
#  Normalization)
#
#  batch_normalization_428 (Batch  (None, 7, 7, 32)    96          ['conv2d_426[0][0]']
#  Normalization)
#
#  batch_normalization_431 (Batch  (None, 7, 7, 64)    192         ['conv2d_429[0][0]']
#  Normalization)
#
#  activation_424 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_426[0][0]']
#
#  activation_426 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_428[0][0]']
#
#  activation_429 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_431[0][0]']
#
#  block35_2_mixed (Concatenate)  (None, 7, 7, 128)    0           ['activation_424[0][0]',
#                                                                   'activation_426[0][0]',
#                                                                   'activation_429[0][0]']
#
#  block35_2_conv (Conv2D)        (None, 7, 7, 320)    41280       ['block35_2_mixed[0][0]']
#
#  custom_scale_layer_81 (CustomS  (None, 7, 7, 320)   0           ['block35_1_ac[0][0]',
#  caleLayer)                                                       'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)      (None, 7, 7, 320)    0           ['custom_scale_layer_81[0][0]']
#
#  conv2d_433 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_2_ac[0][0]']
#
#  batch_normalization_435 (Batch  (None, 7, 7, 32)    96          ['conv2d_433[0][0]']
#  Normalization)
#
#  activation_433 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_435[0][0]']
#
#  conv2d_431 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_2_ac[0][0]']
#
#  conv2d_434 (Conv2D)            (None, 7, 7, 48)     13824       ['activation_433[0][0]']
#
#  batch_normalization_433 (Batch  (None, 7, 7, 32)    96          ['conv2d_431[0][0]']
#  Normalization)
#
#  batch_normalization_436 (Batch  (None, 7, 7, 48)    144         ['conv2d_434[0][0]']
#  Normalization)
#
#  activation_431 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_433[0][0]']
#
#  activation_434 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_436[0][0]']
#
#  conv2d_430 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_2_ac[0][0]']
#
#  conv2d_432 (Conv2D)            (None, 7, 7, 32)     9216        ['activation_431[0][0]']
#
#  conv2d_435 (Conv2D)            (None, 7, 7, 64)     27648       ['activation_434[0][0]']
#
#  batch_normalization_432 (Batch  (None, 7, 7, 32)    96          ['conv2d_430[0][0]']
#  Normalization)
#
#  batch_normalization_434 (Batch  (None, 7, 7, 32)    96          ['conv2d_432[0][0]']
#  Normalization)
#
#  batch_normalization_437 (Batch  (None, 7, 7, 64)    192         ['conv2d_435[0][0]']
#  Normalization)
#
#  activation_430 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_432[0][0]']
#
#  activation_432 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_434[0][0]']
#
#  activation_435 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_437[0][0]']
#
#  block35_3_mixed (Concatenate)  (None, 7, 7, 128)    0           ['activation_430[0][0]',
#                                                                   'activation_432[0][0]',
#                                                                   'activation_435[0][0]']
#
#  block35_3_conv (Conv2D)        (None, 7, 7, 320)    41280       ['block35_3_mixed[0][0]']
#
#  custom_scale_layer_82 (CustomS  (None, 7, 7, 320)   0           ['block35_2_ac[0][0]',
#  caleLayer)                                                       'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)      (None, 7, 7, 320)    0           ['custom_scale_layer_82[0][0]']
#
#  conv2d_439 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_3_ac[0][0]']
#
#  batch_normalization_441 (Batch  (None, 7, 7, 32)    96          ['conv2d_439[0][0]']
#  Normalization)
#
#  activation_439 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_441[0][0]']
#
#  conv2d_437 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_3_ac[0][0]']
#
#  conv2d_440 (Conv2D)            (None, 7, 7, 48)     13824       ['activation_439[0][0]']
#
#  batch_normalization_439 (Batch  (None, 7, 7, 32)    96          ['conv2d_437[0][0]']
#  Normalization)
#
#  batch_normalization_442 (Batch  (None, 7, 7, 48)    144         ['conv2d_440[0][0]']
#  Normalization)
#
#  activation_437 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_439[0][0]']
#
#  activation_440 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_442[0][0]']
#
#  conv2d_436 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_3_ac[0][0]']
#
#  conv2d_438 (Conv2D)            (None, 7, 7, 32)     9216        ['activation_437[0][0]']
#
#  conv2d_441 (Conv2D)            (None, 7, 7, 64)     27648       ['activation_440[0][0]']
#
#  batch_normalization_438 (Batch  (None, 7, 7, 32)    96          ['conv2d_436[0][0]']
#  Normalization)
#
#  batch_normalization_440 (Batch  (None, 7, 7, 32)    96          ['conv2d_438[0][0]']
#  Normalization)
#
#  batch_normalization_443 (Batch  (None, 7, 7, 64)    192         ['conv2d_441[0][0]']
#  Normalization)
#
#  activation_436 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_438[0][0]']
#
#  activation_438 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_440[0][0]']
#
#  activation_441 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_443[0][0]']
#
#  block35_4_mixed (Concatenate)  (None, 7, 7, 128)    0           ['activation_436[0][0]',
#                                                                   'activation_438[0][0]',
#                                                                   'activation_441[0][0]']
#
#  block35_4_conv (Conv2D)        (None, 7, 7, 320)    41280       ['block35_4_mixed[0][0]']
#
#  custom_scale_layer_83 (CustomS  (None, 7, 7, 320)   0           ['block35_3_ac[0][0]',
#  caleLayer)                                                       'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)      (None, 7, 7, 320)    0           ['custom_scale_layer_83[0][0]']
#
#  conv2d_445 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_4_ac[0][0]']
#
#  batch_normalization_447 (Batch  (None, 7, 7, 32)    96          ['conv2d_445[0][0]']
#  Normalization)
#
#  activation_445 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_447[0][0]']
#
#  conv2d_443 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_4_ac[0][0]']
#
#  conv2d_446 (Conv2D)            (None, 7, 7, 48)     13824       ['activation_445[0][0]']
#
#  batch_normalization_445 (Batch  (None, 7, 7, 32)    96          ['conv2d_443[0][0]']
#  Normalization)
#
#  batch_normalization_448 (Batch  (None, 7, 7, 48)    144         ['conv2d_446[0][0]']
#  Normalization)
#
#  activation_443 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_445[0][0]']
#
#  activation_446 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_448[0][0]']
#
#  conv2d_442 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_4_ac[0][0]']
#
#  conv2d_444 (Conv2D)            (None, 7, 7, 32)     9216        ['activation_443[0][0]']
#
#  conv2d_447 (Conv2D)            (None, 7, 7, 64)     27648       ['activation_446[0][0]']
#
#  batch_normalization_444 (Batch  (None, 7, 7, 32)    96          ['conv2d_442[0][0]']
#  Normalization)
#
#  batch_normalization_446 (Batch  (None, 7, 7, 32)    96          ['conv2d_444[0][0]']
#  Normalization)
#
#  batch_normalization_449 (Batch  (None, 7, 7, 64)    192         ['conv2d_447[0][0]']
#  Normalization)
#
#  activation_442 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_444[0][0]']
#
#  activation_444 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_446[0][0]']
#
#  activation_447 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_449[0][0]']
#
#  block35_5_mixed (Concatenate)  (None, 7, 7, 128)    0           ['activation_442[0][0]',
#                                                                   'activation_444[0][0]',
#                                                                   'activation_447[0][0]']
#
#  block35_5_conv (Conv2D)        (None, 7, 7, 320)    41280       ['block35_5_mixed[0][0]']
#
#  custom_scale_layer_84 (CustomS  (None, 7, 7, 320)   0           ['block35_4_ac[0][0]',
#  caleLayer)                                                       'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)      (None, 7, 7, 320)    0           ['custom_scale_layer_84[0][0]']
#
#  conv2d_451 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_5_ac[0][0]']
#
#  batch_normalization_453 (Batch  (None, 7, 7, 32)    96          ['conv2d_451[0][0]']
#  Normalization)
#
#  activation_451 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_453[0][0]']
#
#  conv2d_449 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_5_ac[0][0]']
#
#  conv2d_452 (Conv2D)            (None, 7, 7, 48)     13824       ['activation_451[0][0]']
#
#  batch_normalization_451 (Batch  (None, 7, 7, 32)    96          ['conv2d_449[0][0]']
#  Normalization)
#
#  batch_normalization_454 (Batch  (None, 7, 7, 48)    144         ['conv2d_452[0][0]']
#  Normalization)
#
#  activation_449 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_451[0][0]']
#
#  activation_452 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_454[0][0]']
#
#  conv2d_448 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_5_ac[0][0]']
#
#  conv2d_450 (Conv2D)            (None, 7, 7, 32)     9216        ['activation_449[0][0]']
#
#  conv2d_453 (Conv2D)            (None, 7, 7, 64)     27648       ['activation_452[0][0]']
#
#  batch_normalization_450 (Batch  (None, 7, 7, 32)    96          ['conv2d_448[0][0]']
#  Normalization)
#
#  batch_normalization_452 (Batch  (None, 7, 7, 32)    96          ['conv2d_450[0][0]']
#  Normalization)
#
#  batch_normalization_455 (Batch  (None, 7, 7, 64)    192         ['conv2d_453[0][0]']
#  Normalization)
#
#  activation_448 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_450[0][0]']
#
#  activation_450 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_452[0][0]']
#
#  activation_453 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_455[0][0]']
#
#  block35_6_mixed (Concatenate)  (None, 7, 7, 128)    0           ['activation_448[0][0]',
#                                                                   'activation_450[0][0]',
#                                                                   'activation_453[0][0]']
#
#  block35_6_conv (Conv2D)        (None, 7, 7, 320)    41280       ['block35_6_mixed[0][0]']
#
#  custom_scale_layer_85 (CustomS  (None, 7, 7, 320)   0           ['block35_5_ac[0][0]',
#  caleLayer)                                                       'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)      (None, 7, 7, 320)    0           ['custom_scale_layer_85[0][0]']
#
#  conv2d_457 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_6_ac[0][0]']
#
#  batch_normalization_459 (Batch  (None, 7, 7, 32)    96          ['conv2d_457[0][0]']
#  Normalization)
#
#  activation_457 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_459[0][0]']
#
#  conv2d_455 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_6_ac[0][0]']
#
#  conv2d_458 (Conv2D)            (None, 7, 7, 48)     13824       ['activation_457[0][0]']
#
#  batch_normalization_457 (Batch  (None, 7, 7, 32)    96          ['conv2d_455[0][0]']
#  Normalization)
#
#  batch_normalization_460 (Batch  (None, 7, 7, 48)    144         ['conv2d_458[0][0]']
#  Normalization)
#
#  activation_455 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_457[0][0]']
#
#  activation_458 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_460[0][0]']
#
#  conv2d_454 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_6_ac[0][0]']
#
#  conv2d_456 (Conv2D)            (None, 7, 7, 32)     9216        ['activation_455[0][0]']
#
#  conv2d_459 (Conv2D)            (None, 7, 7, 64)     27648       ['activation_458[0][0]']
#
#  batch_normalization_456 (Batch  (None, 7, 7, 32)    96          ['conv2d_454[0][0]']
#  Normalization)
#
#  batch_normalization_458 (Batch  (None, 7, 7, 32)    96          ['conv2d_456[0][0]']
#  Normalization)
#
#  batch_normalization_461 (Batch  (None, 7, 7, 64)    192         ['conv2d_459[0][0]']
#  Normalization)
#
#  activation_454 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_456[0][0]']
#
#  activation_456 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_458[0][0]']
#
#  activation_459 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_461[0][0]']
#
#  block35_7_mixed (Concatenate)  (None, 7, 7, 128)    0           ['activation_454[0][0]',
#                                                                   'activation_456[0][0]',
#                                                                   'activation_459[0][0]']
#
#  block35_7_conv (Conv2D)        (None, 7, 7, 320)    41280       ['block35_7_mixed[0][0]']
#
#  custom_scale_layer_86 (CustomS  (None, 7, 7, 320)   0           ['block35_6_ac[0][0]',
#  caleLayer)                                                       'block35_7_conv[0][0]']
#
#  block35_7_ac (Activation)      (None, 7, 7, 320)    0           ['custom_scale_layer_86[0][0]']
#
#  conv2d_463 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_7_ac[0][0]']
#
#  batch_normalization_465 (Batch  (None, 7, 7, 32)    96          ['conv2d_463[0][0]']
#  Normalization)
#
#  activation_463 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_465[0][0]']
#
#  conv2d_461 (Conv2D)            (None, 7, 7, 32)     10240       ['block35_7_ac[0][0]']
#
#  conv2d_464 (Conv2D)            (None, 7, 7, 48)     13824       ['activation_463[0][0]']
#
#  batch_normalization_463 (Batch  (None, 7, 7, 32)    96          ['conv2d_461[0][0]']
# ...
#
#  batch_normalization_597 (Batch  (None, 1, 1, 224)   672         ['conv2d_595[0][0]']
#  Normalization)
#
#  activation_595 (Activation)    (None, 1, 1, 224)    0           ['batch_normalization_597[0][0]']
#
#  conv2d_593 (Conv2D)            (None, 1, 1, 192)    399360      ['block8_6_ac[0][0]']
#
#  conv2d_596 (Conv2D)            (None, 1, 1, 256)    172032      ['activation_595[0][0]']
#
#  batch_normalization_595 (Batch  (None, 1, 1, 192)   576         ['conv2d_593[0][0]']
#  Normalization)
#
#  batch_normalization_598 (Batch  (None, 1, 1, 256)   768         ['conv2d_596[0][0]']
#  Normalization)
#
#  activation_593 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_595[0][0]']
#
#  activation_596 (Activation)    (None, 1, 1, 256)    0           ['batch_normalization_598[0][0]']
#
#  block8_7_mixed (Concatenate)   (None, 1, 1, 448)    0           ['activation_593[0][0]',
#                                                                   'activation_596[0][0]']
#
#  block8_7_conv (Conv2D)         (None, 1, 1, 2080)   933920      ['block8_7_mixed[0][0]']
#
#  custom_scale_layer_116 (Custom  (None, 1, 1, 2080)  0           ['block8_6_ac[0][0]',
#  ScaleLayer)                                                      'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)       (None, 1, 1, 2080)   0           ['custom_scale_layer_116[0][0]']
#
#  conv2d_598 (Conv2D)            (None, 1, 1, 192)    399360      ['block8_7_ac[0][0]']
#
#  batch_normalization_600 (Batch  (None, 1, 1, 192)   576         ['conv2d_598[0][0]']
#  Normalization)
#
#  activation_598 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_600[0][0]']
#
#  conv2d_599 (Conv2D)            (None, 1, 1, 224)    129024      ['activation_598[0][0]']
#
#  batch_normalization_601 (Batch  (None, 1, 1, 224)   672         ['conv2d_599[0][0]']
#  Normalization)
#
#  activation_599 (Activation)    (None, 1, 1, 224)    0           ['batch_normalization_601[0][0]']
#
#  conv2d_597 (Conv2D)            (None, 1, 1, 192)    399360      ['block8_7_ac[0][0]']
#
#  conv2d_600 (Conv2D)            (None, 1, 1, 256)    172032      ['activation_599[0][0]']
#
#  batch_normalization_599 (Batch  (None, 1, 1, 192)   576         ['conv2d_597[0][0]']
#  Normalization)
#
#  batch_normalization_602 (Batch  (None, 1, 1, 256)   768         ['conv2d_600[0][0]']
#  Normalization)
#
#  activation_597 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_599[0][0]']
#
#  activation_600 (Activation)    (None, 1, 1, 256)    0           ['batch_normalization_602[0][0]']
#
#  block8_8_mixed (Concatenate)   (None, 1, 1, 448)    0           ['activation_597[0][0]',
#                                                                   'activation_600[0][0]']
#
#  block8_8_conv (Conv2D)         (None, 1, 1, 2080)   933920      ['block8_8_mixed[0][0]']
#
#  custom_scale_layer_117 (Custom  (None, 1, 1, 2080)  0           ['block8_7_ac[0][0]',
#  ScaleLayer)                                                      'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)       (None, 1, 1, 2080)   0           ['custom_scale_layer_117[0][0]']
#
#  conv2d_602 (Conv2D)            (None, 1, 1, 192)    399360      ['block8_8_ac[0][0]']
#
#  batch_normalization_604 (Batch  (None, 1, 1, 192)   576         ['conv2d_602[0][0]']
#  Normalization)
#
#  activation_602 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_604[0][0]']
#
#  conv2d_603 (Conv2D)            (None, 1, 1, 224)    129024      ['activation_602[0][0]']
#
#  batch_normalization_605 (Batch  (None, 1, 1, 224)   672         ['conv2d_603[0][0]']
#  Normalization)
#
#  activation_603 (Activation)    (None, 1, 1, 224)    0           ['batch_normalization_605[0][0]']
#
#  conv2d_601 (Conv2D)            (None, 1, 1, 192)    399360      ['block8_8_ac[0][0]']
#
#  conv2d_604 (Conv2D)            (None, 1, 1, 256)    172032      ['activation_603[0][0]']
#
#  batch_normalization_603 (Batch  (None, 1, 1, 192)   576         ['conv2d_601[0][0]']
#  Normalization)
#
#  batch_normalization_606 (Batch  (None, 1, 1, 256)   768         ['conv2d_604[0][0]']
#  Normalization)
#
#  activation_601 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_603[0][0]']
#
#  activation_604 (Activation)    (None, 1, 1, 256)    0           ['batch_normalization_606[0][0]']
#
#  block8_9_mixed (Concatenate)   (None, 1, 1, 448)    0           ['activation_601[0][0]',
#                                                                   'activation_604[0][0]']
#
#  block8_9_conv (Conv2D)         (None, 1, 1, 2080)   933920      ['block8_9_mixed[0][0]']
#
#  custom_scale_layer_118 (Custom  (None, 1, 1, 2080)  0           ['block8_8_ac[0][0]',
#  ScaleLayer)                                                      'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)       (None, 1, 1, 2080)   0           ['custom_scale_layer_118[0][0]']
#
#  conv2d_606 (Conv2D)            (None, 1, 1, 192)    399360      ['block8_9_ac[0][0]']
#
#  batch_normalization_608 (Batch  (None, 1, 1, 192)   576         ['conv2d_606[0][0]']
#  Normalization)
#
#  activation_606 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_608[0][0]']
#
#  conv2d_607 (Conv2D)            (None, 1, 1, 224)    129024      ['activation_606[0][0]']
#
#  batch_normalization_609 (Batch  (None, 1, 1, 224)   672         ['conv2d_607[0][0]']
#  Normalization)
#
#  activation_607 (Activation)    (None, 1, 1, 224)    0           ['batch_normalization_609[0][0]']
#
#  conv2d_605 (Conv2D)            (None, 1, 1, 192)    399360      ['block8_9_ac[0][0]']
#
#  conv2d_608 (Conv2D)            (None, 1, 1, 256)    172032      ['activation_607[0][0]']
#
#  batch_normalization_607 (Batch  (None, 1, 1, 192)   576         ['conv2d_605[0][0]']
#  Normalization)
#
#  batch_normalization_610 (Batch  (None, 1, 1, 256)   768         ['conv2d_608[0][0]']
#  Normalization)
#
#  activation_605 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_607[0][0]']
#
#  activation_608 (Activation)    (None, 1, 1, 256)    0           ['batch_normalization_610[0][0]']
#
#  block8_10_mixed (Concatenate)  (None, 1, 1, 448)    0           ['activation_605[0][0]',
#                                                                   'activation_608[0][0]']
#
#  block8_10_conv (Conv2D)        (None, 1, 1, 2080)   933920      ['block8_10_mixed[0][0]']
#
#  custom_scale_layer_119 (Custom  (None, 1, 1, 2080)  0           ['block8_9_ac[0][0]',
#  ScaleLayer)                                                      'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)               (None, 1, 1, 1536)   3194880     ['custom_scale_layer_119[0][0]']
#
#  conv_7b_bn (BatchNormalization  (None, 1, 1, 1536)  4608        ['conv_7b[0][0]']
#  )
#
#  conv_7b_ac (Activation)        (None, 1, 1, 1536)   0           ['conv_7b_bn[0][0]']
#
#  batch_normalization_611 (Batch  (None, 1, 1, 1536)  6144        ['conv_7b_ac[0][0]']
#  Normalization)
#
#  global_average_pooling2d_2 (Gl  (None, 1536)        0           ['batch_normalization_611[0][0]']
#  obalAveragePooling2D)
#
#  dense_2 (Dense)                (None, 3)            4611        ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 54,347,491
# Trainable params: 7,683
# Non-trainable params: 54,339,808
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.losses import SparseCategoricalCrossentropy
model.compile(loss=SparseCategoricalCrossentropy(),
       optimizer="adam",
       metrics=["accuracy"])

# %%
import datetime
import tensorflow as tf
from tensorboard.plugins.hparams import api as hp
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
callbacks = [
    ModelCheckpoint("/content/drive/MyDrive/InceptionResNetV2/cnn.h5", save_best_only=True),
    # 檢查test資料, 如果我10次都沒有表現更好, 停
    EarlyStopping(patience=10, restore_best_weights=True)
]

log_dir="logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(
    log_dir=log_dir, histogram_freq=1)
hparams_callback = hp.KerasCallback(log_dir, {
    'num_relu_units': 512,
    'dropout': 0.2
})

# 不想要進度條, verbose=2
model.fit(training_set,
     epochs=100,
     validation_data=validate_set,
     callbacks=callbacks,
     verbose=2)
# Out:
# Epoch 1/100
# 3/3 - 26s - loss: 1.5031 - accuracy: 0.3298 - val_loss: 1.2373 - val_accuracy: 0.3750 - 26s/epoch - 9s/step
# Epoch 2/100
# 3/3 - 1s - loss: 1.1966 - accuracy: 0.4894 - val_loss: 1.6978 - val_accuracy: 0.1250 - 789ms/epoch - 263ms/step
# Epoch 3/100
# 3/3 - 1s - loss: 1.0514 - accuracy: 0.5638 - val_loss: 1.3034 - val_accuracy: 0.1250 - 804ms/epoch - 268ms/step
# Epoch 4/100
# 3/3 - 3s - loss: 0.9380 - accuracy: 0.6170 - val_loss: 0.9845 - val_accuracy: 0.5000 - 3s/epoch - 1s/step
# Epoch 5/100
# 3/3 - 4s - loss: 0.8351 - accuracy: 0.6277 - val_loss: 0.8592 - val_accuracy: 0.6250 - 4s/epoch - 1s/step
# Epoch 6/100
# 3/3 - 3s - loss: 0.7208 - accuracy: 0.7660 - val_loss: 0.7719 - val_accuracy: 0.6250 - 3s/epoch - 1s/step
# Epoch 7/100
# 3/3 - 3s - loss: 0.6666 - accuracy: 0.7872 - val_loss: 0.7102 - val_accuracy: 0.7500 - 3s/epoch - 1s/step
# Epoch 8/100
# 3/3 - 4s - loss: 0.5536 - accuracy: 0.8404 - val_loss: 0.6890 - val_accuracy: 0.7500 - 4s/epoch - 1s/step
# Epoch 9/100
# 3/3 - 1s - loss: 0.5092 - accuracy: 0.8085 - val_loss: 0.6986 - val_accuracy: 0.7500 - 781ms/epoch - 260ms/step
# Epoch 10/100
# 3/3 - 3s - loss: 0.4054 - accuracy: 0.9468 - val_loss: 0.6887 - val_accuracy: 0.7500 - 3s/epoch - 1s/step
# Epoch 11/100
# 3/3 - 3s - loss: 0.3825 - accuracy: 0.9787 - val_loss: 0.6369 - val_accuracy: 0.7500 - 3s/epoch - 1s/step
# Epoch 12/100
# 3/3 - 3s - loss: 0.3354 - accuracy: 0.9574 - val_loss: 0.6286 - val_accuracy: 0.7500 - 3s/epoch - 1s/step
# Epoch 13/100
# 3/3 - 1s - loss: 0.2572 - accuracy: 0.9894 - val_loss: 0.6629 - val_accuracy: 0.7500 - 794ms/epoch - 265ms/step
# Epoch 14/100
# 3/3 - 1s - loss: 0.2513 - accuracy: 0.9894 - val_loss: 0.6656 - val_accuracy: 0.6250 - 809ms/epoch - 270ms/step
# Epoch 15/100
# 3/3 - 1s - loss: 0.2242 - accuracy: 0.9787 - val_loss: 0.6294 - val_accuracy: 0.6250 - 817ms/epoch - 272ms/step
# Epoch 16/100
# 3/3 - 4s - loss: 0.1785 - accuracy: 1.0000 - val_loss: 0.6186 - val_accuracy: 0.6250 - 4s/epoch - 1s/step
# Epoch 17/100
# 3/3 - 1s - loss: 0.1495 - accuracy: 1.0000 - val_loss: 0.6190 - val_accuracy: 0.6250 - 798ms/epoch - 266ms/step
# Epoch 18/100
# 3/3 - 1s - loss: 0.1335 - accuracy: 1.0000 - val_loss: 0.6307 - val_accuracy: 0.6250 - 810ms/epoch - 270ms/step
# Epoch 19/100
# 3/3 - 1s - loss: 0.1626 - accuracy: 0.9787 - val_loss: 0.6549 - val_accuracy: 0.6250 - 826ms/epoch - 275ms/step
# Epoch 20/100
# 3/3 - 1s - loss: 0.1380 - accuracy: 0.9787 - val_loss: 0.6722 - val_accuracy: 0.6250 - 809ms/epoch - 270ms/step
# Epoch 21/100
# 3/3 - 1s - loss: 0.0973 - accuracy: 1.0000 - val_loss: 0.7044 - val_accuracy: 0.6250 - 776ms/epoch - 259ms/step
# Epoch 22/100
# 3/3 - 1s - loss: 0.0949 - accuracy: 1.0000 - val_loss: 0.7330 - val_accuracy: 0.6250 - 1s/epoch - 475ms/step
# Epoch 23/100
# 3/3 - 1s - loss: 0.0955 - accuracy: 0.9787 - val_loss: 0.7616 - val_accuracy: 0.6250 - 839ms/epoch - 280ms/step
# Epoch 24/100
# 3/3 - 1s - loss: 0.0881 - accuracy: 0.9894 - val_loss: 0.7708 - val_accuracy: 0.6250 - 798ms/epoch - 266ms/step
# Epoch 25/100
# 3/3 - 1s - loss: 0.0649 - accuracy: 1.0000 - val_loss: 0.7675 - val_accuracy: 0.6250 - 782ms/epoch - 261ms/step
# Epoch 26/100
# 3/3 - 2s - loss: 0.0588 - accuracy: 1.0000 - val_loss: 0.7406 - val_accuracy: 0.6250 - 2s/epoch - 549ms/step

# %%
from tensorflow.keras.models import load_model
model= load_model("/content/drive/MyDrive/InceptionResNetV2/Skirt/*.h5")

# %%
model.evaluate(test_set)
# Out:
# 1/1 [==============================] - 0s 168ms/step - loss: 0.7038 - accuracy: 0.5000
# [0.7038396596908569, 0.5]

# %%
model.predict(test_set)
# Out:
# WARNING:tensorflow:5 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fccd4e7f520> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 4s 4s/step
# array([[0.3179175 , 0.08222816, 0.5998543 ],
#        [0.00470896, 0.03512794, 0.9601631 ],
#        [0.01448563, 0.01407112, 0.9714433 ],
#        [0.07684365, 0.65548253, 0.26767376],
#        [0.01470674, 0.21800752, 0.76728576],
#        [0.06106097, 0.32246846, 0.6164706 ],
#        [0.24458666, 0.01993624, 0.73547715],
#        [0.01573754, 0.11048701, 0.8737755 ]], dtype=float32)

# %%
import numpy as np
from tensorflow.keras.preprocessing.image import load_img
def getdata(df):
  img_org, img_preprocess, target = [], [], []
  for fn, c in zip(df["filename"], df["class"]):
    img = load_img(fn, target_size=(80, 80, 3))
    img_org.append(img)
    img_np = np.array(img)
    img = preprocess_input(img_np)
    img_preprocess.append(img)
    target.append(c)
  return np.array(img_org), np.array(img_preprocess), np.array(target)
img_org, x_test, y_test = getdata(test)
print(img_org.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (8,)
# (8, 80, 80, 3)
# (8,)
# <ipython-input-59-f435574e71a8>:12: FutureWarning: The input object of type 'Image' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Image', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   return np.array(img_org), np.array(img_preprocess), np.array(target)
# <ipython-input-59-f435574e71a8>:12: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(img_org), np.array(img_preprocess), np.array(target)

# %%
pre = model.predict(x_test).argmax(axis=-1)
pre
# Out:
# WARNING:tensorflow:6 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fccd4e7f520> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 3s 3s/step
# array([2, 2, 2, 2, 2, 2, 1, 2])

# %%
y_test
# Out:
# array([0, 1, 1, 2, 2, 2, 2, 2])

# %%
idx = np.nonzero(pre != y_test)[0]
idx
# Out:
# array([0, 1, 2, 6])

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd
cm = confusion_matrix(y_test, pre)
pd.DataFrame(cm, columns=["Naturel(P)", "Straight(P)", "Wave(P)"], index=["Naturel(T)", "Straight(T)", "Wave(T)"])
# Out:
#              Naturel(P)  Straight(P)  Wave(P)
# Naturel(T)            0            0        1
# Straight(T)           0            0        2
# Wave(T)               0            1        4

# %%
# imports
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

cm = confusion_matrix(y_test, pre)

plt.figure(figsize=(12,10))

# Using Seaborn heatmap to create the plot
fx = sns.heatmap(cm, annot=True, cmap=plt.cm.Blues)

# labels the title and x, y axis of plot
fx.set_title('Confusion Matrix\n', fontsize=20);
fx.set_xlabel('\nPredicted', fontsize=20)
fx.set_ylabel('Actual\n', fontsize=20);

# labels the boxes
fx.xaxis.set_ticklabels(["Naturel", "Straight", "Wave"], fontsize=15)
fx.yaxis.set_ticklabels(["Naturel", "Straight", "Wave"], fontsize=15)
plt.savefig("/content/drive/MyDrive/InceptionResNetV2/Skirt")
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
trans = ["Naturel", "Straight", "Wave"]
err_img = img_org[idx]
err_y = y_test[idx]
err_pre = pre[idx]
rows = 7
cols = 3
plt.figure(figsize=(12, 30))
for i in range(len(err_img)):
    plt.subplot(rows, cols, i+1)
    t = f"origin: {trans[err_y[i]]}, predict: {trans[err_pre[i]]}"
    plt.title(t)
    plt.axis("off")
    img = err_img[i]
    img_np = np.array(img)
    plt.imshow(img_np)
